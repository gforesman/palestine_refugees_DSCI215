# %%
import pandas as pd 
import numpy as np
import csv as csv
import seaborn as sns
import matplotlib.pyplot as plt

# %%
#population data 
unrwaPop = pd.read_csv("/workspaces/palestine_refugees_DSCI215/datasets/unrwa_totalpop.csv")
unrwaPop

#demo data 2019 onward 
unrwaDemo = pd.read_csv("/workspaces/palestine_refugees_DSCI215/datasets/unrwaDEMO_CleanLong.csv")
unrwaDemo
# Out:
#      Unnamed: 0  year       origin              asylum population_type  \
# 0             1  2019  Palestinian  State of Palestine      female_0-4
# 1             2  2019  Palestinian  State of Palestine     female_5-11
# 2             3  2019  Palestinian  State of Palestine    female_12-17
# 3             4  2019  Palestinian  State of Palestine    female_18-59
# 4             5  2019  Palestinian  State of Palestine       female_60
# ..          ...   ...          ...                 ...             ...
# 295         296  2023  Palestinian    Syrian Arab Rep.         male_60
# 296         297  2023  Palestinian    Syrian Arab Rep.      male_total
# 297         298  2023  Palestinian    Syrian Arab Rep.           total
# 298         299  2023  Palestinian    Syrian Arab Rep.     f_minor_all
# 299         300  2023  Palestinian    Syrian Arab Rep.     m_minor_all
#
#      population  gender        age
# 0        115683  female        0-4
# 1        139189  female       5-11
# 2        145473  female      12-17
# 3        620567  female      18-59
# 4        124911  female         60
# ..          ...     ...        ...
# 295       39308    male         60
# 296      292666    male      total
# 297      586578   total        NaN
# 298       83262       f  minor_all
# 299       86537       m  minor_all
#
# [300 rows x 8 columns]

# %%
#df showing total number of refugees under unrwa 
unrwaYearSum = unrwaPop[['Year', 'Total']].groupby('Year').sum().reset_index()
unrwaYearSum

#pseYearSum = pseAll[['population', 'year', 'population_group']].groupby(['year', 'population_group'])['population'].sum().to_frame().reset_index()
# Out:
#     Year    Total
# 0   1952   867458
# 1   1953   874596
# 2   1954   895249
# 3   1955   912425
# 4   1956   924922
# ..   ...      ...
# 68  2020  5703521
# 69  2021  5792907
# 70  2022  5887353
# 71  2023  5968636
# 72  2024  5975950
#
# [73 rows x 2 columns]

# %%
#creating a graph to show overall trend of UNRWA refugees 
unrwaYear_line = sns.lineplot(data = unrwaYearSum,
                            x = 'Year', y = 'Total',
                            markers='o')
sns.set_style('darkgrid')
plt.title('Total Number of Refugees under UNRWA mandate, 1954-2024')
plt.yticks([0, 1000000, 2000000, 3000000, 4000000, 5000000, 6000000], ['0', '1,000,000', '2,000,000', '3,000,000', '4,000,000', '5,000,000', '6,000,000'])
plt.show()

# %%
#graphing by country 
unrwaAll_line = sns.lineplot(data = unrwaPop,
                            x = 'Year', y = 'Total', hue = 'Country of asylum',
                            markers='o')
sns.set_style('darkgrid')
plt.title('Total Number of Refugees under UNRWA mandate by country, 1954-2024')
plt.yticks([0, 500000, 1000000, 1500000, 2000000, 2500000], ['0', '500,000', '1,000,000', '1,500,000', '2,000,000', '2,500,000'])
plt.show()

# %%
#looking at demographics 

#pulling only demographic info from 2023 
unrwa2023 = unrwaDemo[(unrwaDemo['year'] == 2023) & (~unrwaDemo['population_type'].str.contains('all|total'))]
unrwa2023

#converting male to neg
# convert male counts to negative
unrwa2023.loc[unrwa2023.gender.eq('male'), 'population'] = unrwa2023.population.mul(-1)
unrwa2023
# Out:
#      Unnamed: 0  year       origin              asylum population_type  \
# 240         241  2023  Palestinian  State of Palestine      female_0-4
# 241         242  2023  Palestinian  State of Palestine     female_5-11
# 242         243  2023  Palestinian  State of Palestine    female_12-17
# 243         244  2023  Palestinian  State of Palestine    female_18-59
# 244         245  2023  Palestinian  State of Palestine       female_60
# 246         247  2023  Palestinian  State of Palestine        male_0-4
# 247         248  2023  Palestinian  State of Palestine       male_5-11
# 248         249  2023  Palestinian  State of Palestine      male_12-17
# 249         250  2023  Palestinian  State of Palestine      male_18-59
# 250         251  2023  Palestinian  State of Palestine         male_60
# 255         256  2023  Palestinian              Jordan      female_0-4
# 256         257  2023  Palestinian              Jordan     female_5-11
# 257         258  2023  Palestinian              Jordan    female_12-17
# 258         259  2023  Palestinian              Jordan    female_18-59
# 259         260  2023  Palestinian              Jordan       female_60
# 261         262  2023  Palestinian              Jordan        male_0-4
# 262         263  2023  Palestinian              Jordan       male_5-11
# 263         264  2023  Palestinian              Jordan      male_12-17
# 264         265  2023  Palestinian              Jordan      male_18-59
# 265         266  2023  Palestinian              Jordan         male_60
# 270         271  2023  Palestinian             Lebanon      female_0-4
# 271         272  2023  Palestinian             Lebanon     female_5-11
# 272         273  2023  Palestinian             Lebanon    female_12-17
# 273         274  2023  Palestinian             Lebanon    female_18-59
# 274         275  2023  Palestinian             Lebanon       female_60
# 276         277  2023  Palestinian             Lebanon        male_0-4
# 277         278  2023  Palestinian             Lebanon       male_5-11
# 278         279  2023  Palestinian             Lebanon      male_12-17
# 279         280  2023  Palestinian             Lebanon      male_18-59
# 280         281  2023  Palestinian             Lebanon         male_60
# 285         286  2023  Palestinian    Syrian Arab Rep.      female_0-4
# 286         287  2023  Palestinian    Syrian Arab Rep.     female_5-11
# 287         288  2023  Palestinian    Syrian Arab Rep.    female_12-17
# 288         289  2023  Palestinian    Syrian Arab Rep.    female_18-59
# 289         290  2023  Palestinian    Syrian Arab Rep.       female_60
# 291         292  2023  Palestinian    Syrian Arab Rep.        male_0-4
# 292         293  2023  Palestinian    Syrian Arab Rep.       male_5-11
# 293         294  2023  Palestinian    Syrian Arab Rep.      male_12-17
# 294         295  2023  Palestinian    Syrian Arab Rep.      male_18-59
# 295         296  2023  Palestinian    Syrian Arab Rep.         male_60
#
#      population  gender    age
# 240      104632  female    0-4
# 241      178447  female   5-11
# 242      152950  female  12-17
# 243      648792  female  18-59
# 244      148503  female     60
# 246     -111357    male    0-4
# 247     -188384    male   5-11
# 248     -159770    male  12-17
# 249     -672616    male  18-59
# 250     -131243    male     60
# 255       38871  female    0-4
# 256      109845  female   5-11
# 257      129304  female  12-17
# 258      709550  female  18-59
# 259      182547  female     60
# 261      -41415    male    0-4
# 262     -115346    male   5-11
# 263     -135901    male  12-17
# 264     -741796    male  18-59
# 265     -187956    male     60
# 270       10852  female    0-4
# 271       21147  female   5-11
# 272       19453  female  12-17
# 273      142267  female  18-59
# 274       49304  female     60
# 276      -11413    male    0-4
# 277      -22558    male   5-11
# 278      -20619    male  12-17
# 279     -146929    male  18-59
# 280      -48291    male     60
# 285       16964  female    0-4
# 286       32028  female   5-11
# 287       34270  female  12-17
# 288      164719  female  18-59
# 289       45931  female     60
# 291      -17274    male    0-4
# 292      -33396    male   5-11
# 293      -35867    male  12-17
# 294     -166821    male  18-59
# 295      -39308    male     60

# %%
# population pyramid
sns.barplot(data=unrwa2023, x='population', y='age', hue='gender', orient='horizontal', dodge=False, ci = None, palette="Set2")

#https://stackoverflow.com/questions/63619776/population-pyramid-with-python-and-seaborn
# Out:
# /tmp/ipykernel_2947/3036179811.py:2: FutureWarning:
#
# The `ci` parameter is deprecated. Use `errorbar=None` for the same effect.
#
#   sns.barplot(data=unrwa2023, x='population', y='age', hue='gender', orient='horizontal', dodge=False, ci = None, palette="Set2")
# <Axes: xlabel='population', ylabel='age'>
